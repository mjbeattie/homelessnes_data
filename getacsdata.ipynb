# %% [markdown]
# # getacsdata
# ### First version:  June 18, 2023
# ### Lastest update:  June 18, 2023
# ### Matthew Beattie
# ### University of Oklahoma
#
# This notebook uses the US Census API to download data from the American Community Survey dataset.  The features selected are intended for study of homeless trends.  The method works by calling the API for each year of interest in the study.  It pulls down variables from ACS and then normalizes them into per capita values.

# %%
# Initialize libraries
import requests
import pandas as pd
import numpy as np
import os

# %%
# Set working directory
os.chdir('/Users/mjbeattie/OneDrive/GitHub/homelessness_data')
os.listdir()
# Out:
# ['.DS_Store',
#  'ACS Feature Dictionary.txt',
#  'ACS Feature Dictionary.xlsx',
#  'README.md',
#  'getacsdata.ipynb',
#  '.ipynb_checkpoints',
#  'Political Landscape Study.xlsx',
#  'acs_feature_dictionary.txt',
#  '.git']

# %%
# Read in baseline data dictionary
basedict = pd.read_csv('acs_feature_dictionary.txt',sep='\t')
basedict
# Out:
#              Category                                  Feature  \
# 0          Population                                    Total
# 1          Population                                     Male
# 2          Population                                   Female
# 3          Population                           White Not Hisp
# 4          Population                              Black Alone
# 5          Population                           Amer Indian/AK
# 6          Population                              Asian Alone
# 7          Population                             Native HI/PI
# 8          Population                                    Other
# 9          Population                              Two or more
# 10         Population                                 Hispanic
# 11         Population                               Median Age
# 12           Mobility                         Total population
# 13           Mobility                               Non-movers
# 14           Mobility                              Same county
# 15           Mobility                  Same state, diff county
# 16           Mobility                          Different state
# 17           Mobility                        Different country
# 18      Poverty Level                                    Total
# 19      Poverty Level    Ratio of income to poverty level <0.5
# 20      Poverty Level                                 0.5-0.74
# 21      Poverty Level                                0.75-0.99
# 22      Poverty Level                                 1.0-1.24
# 23      Poverty Level                                1.25-1.49
# 24      Poverty Level                                 1.5-1.74
# 25      Poverty Level                                1.75-1.84
# 26      Poverty Level                                1.85-1.99
# 27    Median Earnings                          Median earnings
# 28         Assistance                         Total households
# 29         Assistance                      Received assistance
# 30         Employment               Total population 16+ years
# 31         Employment                       Not in labor force
# 32  Housing-Occupancy                              Total units
# 33  Housing-Occupancy                                   Vacant
# 34             Tenure                     Total occupied units
# 35             Tenure                             Rented units
# 36            Vacancy                              Total units
# 37            Vacancy                                 For rent
# 38            Vacancy                                 For sale
# 39     Household size                                    Total
# 40     Household size                           Owner occupied
# 41     Household size                          Renter occupied
# 42    Number of rooms                             Median total
# 43    Number of rooms                           Owner occupied
# 44    Number of rooms                          Renter occupied
# 45               Rent     Gross rent as pct of HH income total
# 46               Rent                                      <10
# 47               Rent                                  10-14.9
# 48               Rent                                  15-19.9
# 49               Rent                                  20-24.9
# 50               Rent                                  25-29.9
# 51               Rent                                  30-34.9
# 52               Rent                                  35-39.9
# 53               Rent                                  40-49.9
# 54               Rent                                      50+
# 55               Rent  Median gross rent as a pct of HH income
#
#               Alias ACS Field Name     Per Capita Value
# 0           pop_tot    B01001_001E          pop_tot_pcp
# 1          pop_male    B01001_002E         pop_male_pcp
# 2        pop_female    B01001_003E       pop_female_pcp
# 3         pop_white   B01001H_001E        pop_white_pcp
# 4         pop_black   B01001B_001E        pop_black_pcp
# 5          pop_aiak   B01001C_001E         pop_aiak_pcp
# 6         pop_asian   B01001D_001E        pop_asian_pcp
# 7          pop_hipi   B01001E_001E         pop_hipi_pcp
# 8         pop_other   B01001F_001E        pop_other_pcp
# 9          pop_mult   B01001G_001E         pop_mult_pcp
# 10         pop_hisp   B01001I_001E         pop_hisp_pcp
# 11       pop_medage    B01002_001E       pop_medage_pcp
# 12          mob_tot    B07001_001E          mob_tot_pcp
# 13       mob_nomove    B07001_017E       mob_nomove_pcp
# 14   mob_samecounty    B07001_033E   mob_samecounty_pcp
# 15   mob_diffcounty    B07001_049E   mob_diffcounty_pcp
# 16    mob_diffstate    B07001_065E    mob_diffstate_pcp
# 17    mob_diffcntry    B07001_081E    mob_diffcntry_pcp
# 18        pov_total    B17002_001E        pov_total_pcp
# 19          pov_u50    B17002_002E          pov_u50_pcp
# 20        pov_50t74    B17002_003E        pov_50t74_pcp
# 21        pov_75t99    B17002_004E        pov_75t99_pcp
# 22      pov_100t124    B17002_005E      pov_100t124_pcp
# 23      pov_125t149    B17002_006E      pov_125t149_pcp
# 24      pov_150t174    B17002_007E      pov_150t174_pcp
# 25      pov_175t184    B17002_008E      pov_175t184_pcp
# 26      pov_185t199    B17002_009E      pov_185t199_pcp
# 27       me_medearn    B18140_001E       me_medearn_pcp
# 28       asst_total    B22001_001E       asst_total_pcp
# 29        asst_rcvd    B22001_002E        asst_rcvd_pcp
# 30         empl_tot    B23025_001E         empl_tot_pcp
# 31  empl_notinlabor    B23025_003E  empl_notinlabor_pcp
# 32         occu_tot    B25002_001E         occu_tot_pcp
# 33      occu_vacant    B25002_003E      occu_vacant_pcp
# 34       tenure_tot    B25003_001E       tenure_tot_pcp
# 35      tenure_rent    B25003_003E      tenure_rent_pcp
# 36        vcncy_tot    B25004_001E        vcncy_tot_pcp
# 37    vcncy_forrent    B25004_002E    vcncy_forrent_pcp
# 38    vcncy_forsale    B25004_004E    vcncy_forsale_pcp
# 39       hhsize_tot    B25010_001E       hhsize_tot_pcp
# 40       hhsize_own    B25010_002E       hhsize_own_pcp
# 41      hhsize_rent    B25010_003E      hhsize_rent_pcp
# 42       nbrrms_tot    B25021_001E       nbrrms_tot_pcp
# 43       nbrrms_own    B25021_002E       nbrrms_own_pcp
# 44      nbrrms_rent    B25021_003E      nbrrms_rent_pcp
# 45      rentpct_tot    B25070_001E      rentpct_tot_pcp
# 46      rentpct_u10    B25070_002E      rentpct_u10_pcp
# 47    rentpct_10t14    B25070_003E    rentpct_10t14_pcp
# 48    rentpct_15t19    B25070_004E    rentpct_15t19_pcp
# 49    rentpct_20t24    B25070_005E    rentpct_20t24_pcp
# 50    rentpct_25t29    B25070_006E    rentpct_25t29_pcp
# 51    rentpct_30t34    B25070_007E    rentpct_30t34_pcp
# 52    rentpct_35t39    B25070_008E    rentpct_35t39_pcp
# 53    rentpct_40t49    B25070_009E    rentpct_40t49_pcp
# 54   rentpct_50plus    B25070_010E   rentpct_50plus_pcp
# 55   rentpct_median    B25071_001E   rentpct_median_pcp

# %%
acsfield = 'B01001H_001E'
alias = basedict.loc[basedict['ACS Field Name'] == acsfield, 'Alias'].values[0]
alias
# Out:
# 'pop_white'

# %%
# Save categories in a list to iterate through
categorylist = basedict['Category'].unique().tolist()

# Create tuples of category and field lists
catfields = []
for category in categorylist:
    fieldlist = basedict[basedict['Category']==category]['ACS Field Name'].tolist()
    fieldstr = ','.join(fieldlist)
    catfields.append((category,fieldstr))
# Out:
# [('Population',
#   'B01001_001E,B01001_002E,B01001_003E,B01001H_001E,B01001B_001E,B01001C_001E,B01001D_001E,B01001E_001E,B01001F_001E,B01001G_001E,B01001I_001E,B01002_001E'),
#  ('Mobility',
#   'B07001_001E,B07001_017E,B07001_033E,B07001_049E,B07001_065E,B07001_081E'),
#  ('Poverty Level',
#   'B17002_001E,B17002_002E,B17002_003E,B17002_004E,B17002_005E,B17002_006E,B17002_007E,B17002_008E,B17002_009E'),
#  ('Median Earnings', 'B18140_001E'),
#  ('Assistance', 'B22001_001E,B22001_002E'),
#  ('Employment', 'B23025_001E,B23025_003E'),
#  ('Housing-Occupancy', 'B25002_001E,B25002_003E'),
#  ('Tenure', 'B25003_001E,B25003_003E'),
#  ('Vacancy', 'B25004_001E,B25004_002E,B25004_004E'),
#  ('Household size', 'B25010_001E,B25010_002E,B25010_003E'),
#  ('Number of rooms', 'B25021_001E,B25021_002E,B25021_003E'),
#  ('Rent',
#   'B25070_001E,B25070_002E,B25070_003E,B25070_004E,B25070_005E,B25070_006E,B25070_007E,B25070_008E,B25070_009E,B25070_010E,B25071_001E')]

# %%
# Iterate through catfields and call ACS API
firstcategory = True
for item in catfields:
    # Construct the API call
    baseurl = "https://api.census.gov/data/2019/acs/acs1?get=NAME,"
    geostr = "&for=state:17,18"
    url = baseurl + item[1] + geostr

    payload = {}
    headers = {
        'Cookie': 'TS010383f0=01283c52a4bcbb7610e59eeaa15d8413e26e6fe3964ed3d6366923cf15872dc497c7b99977c06f32b40443b07f2820836b21943cf2'
    }

    # Call the API
    response = requests.request("GET", url, headers=headers, data=payload)
    
    # Save the response as json and create a pandas dataframe from it
    data = response.json()
    df = pd.DataFrame(data[1:], columns=data[0])
    df.drop(['state'],axis=1,inplace=True)
    if firstcategory:
        df = pd.DataFrame(data[1:], columns=data[0])
        df.drop(['state'],axis=1,inplace=True)
    else:
        dfnew = pd.DataFrame(data[1:], columns=data[0])
        dfnew.drop(['NAME','state'],axis=1,inplace=True)
        df = pd.concat([df, dfnew], axis=1)
    firstcategory = False
    
# Add year to dataframe and change NAME to state
df['year']=2019
df = df.rename(columns={'NAME': 'state'})
