# %% [markdown]
# # getacsdata
# ### First version:  June 18, 2023
# ### Lastest update:  June 18, 2023
# ### Matthew Beattie
# ### University of Oklahoma
#
# This notebook uses the US Census API to download data from the American Community Survey dataset.  The features selected are intended for study of homeless trends.  The method works by calling the API for each year of interest in the study.  It pulls down variables from ACS and then normalizes them into per capita values.
#
# The variables included here have not changed from 2011-2021.  Note that there were no ACS data released for the year 2020 due to COVID.  Also, the API didn't work for 2009 or 2010 despite the variables being the same.

# %%
# Initialize libraries
import requests
import pandas as pd
import numpy as np
import os

# %%
# Set working directory
os.chdir('/Users/mjbeattie/OneDrive/GitHub/homelessness_data')
os.listdir()
# Out:
# ['acsdatafeatures.txt',
#  '.DS_Store',
#  'state_abbreviations.txt',
#  'ACS Feature Dictionary.xlsx',
#  'README.md',
#  'getacsdata.ipynb',
#  '.ipynb_checkpoints',
#  'Political Landscape Study.xlsx',
#  'acs_feature_dictionary.txt',
#  '.git']

# %%
# Read in baseline data dictionary
basedict = pd.read_csv('acs_feature_dictionary.txt',sep='\t')
basedict
# Out:
#              Category                                  Feature  \
# 0          Population                                    Total
# 1          Population                                     Male
# 2          Population                                   Female
# 3          Population                           White Not Hisp
# 4          Population                              Black Alone
# 5          Population                           Amer Indian/AK
# 6          Population                              Asian Alone
# 7          Population                             Native HI/PI
# 8          Population                                    Other
# 9          Population                              Two or more
# 10         Population                                 Hispanic
# 11         Population                               Median Age
# 12           Mobility                         Total population
# 13           Mobility                               Non-movers
# 14           Mobility                              Same county
# 15           Mobility                  Same state, diff county
# 16           Mobility                          Different state
# 17           Mobility                        Different country
# 18      Poverty Level                                    Total
# 19      Poverty Level    Ratio of income to poverty level <0.5
# 20      Poverty Level                                 0.5-0.74
# 21      Poverty Level                                0.75-0.99
# 22      Poverty Level                                 1.0-1.24
# 23      Poverty Level                                1.25-1.49
# 24      Poverty Level                                 1.5-1.74
# 25      Poverty Level                                1.75-1.84
# 26      Poverty Level                                1.85-1.99
# 27    Median Earnings                          Median earnings
# 28         Assistance                         Total households
# 29         Assistance                      Received assistance
# 30         Employment               Total population 16+ years
# 31         Employment                       Not in labor force
# 32  Housing-Occupancy                              Total units
# 33  Housing-Occupancy                                   Vacant
# 34             Tenure                     Total occupied units
# 35             Tenure                             Rented units
# 36            Vacancy                              Total units
# 37            Vacancy                                 For rent
# 38            Vacancy                                 For sale
# 39     Household size                                    Total
# 40     Household size                           Owner occupied
# 41     Household size                          Renter occupied
# 42    Number of rooms                             Median total
# 43    Number of rooms                           Owner occupied
# 44    Number of rooms                          Renter occupied
# 45               Rent     Gross rent as pct of HH income total
# 46               Rent                                      <10
# 47               Rent                                  10-14.9
# 48               Rent                                  15-19.9
# 49               Rent                                  20-24.9
# 50               Rent                                  25-29.9
# 51               Rent                                  30-34.9
# 52               Rent                                  35-39.9
# 53               Rent                                  40-49.9
# 54               Rent                                      50+
# 55               Rent  Median gross rent as a pct of HH income
#
#               Alias ACS Field Name        Per Capita Value Per Capita Divisor
# 0           pop_tot    B01001_001E      pop_tot_pcp_remove            pop_tot
# 1          pop_male    B01001_002E            pop_male_pcp            pop_tot
# 2        pop_female    B01001_026E          pop_female_pcp            pop_tot
# 3         pop_white   B01001H_001E           pop_white_pcp            pop_tot
# 4         pop_black   B01001B_001E           pop_black_pcp            pop_tot
# 5          pop_aiak   B01001C_001E            pop_aiak_pcp            pop_tot
# 6         pop_asian   B01001D_001E           pop_asian_pcp            pop_tot
# 7          pop_hipi   B01001E_001E            pop_hipi_pcp            pop_tot
# 8         pop_other   B01001F_001E           pop_other_pcp            pop_tot
# 9          pop_mult   B01001G_001E            pop_mult_pcp            pop_tot
# 10         pop_hisp   B01001I_001E            pop_hisp_pcp            pop_tot
# 11       pop_medage    B01002_001E          pop_medage_pcp                NaN
# 12          mob_tot    B07001_001E      mob_tot_pcp_remove            mob_tot
# 13       mob_nomove    B07001_017E          mob_nomove_pcp            mob_tot
# 14   mob_samecounty    B07001_033E      mob_samecounty_pcp            mob_tot
# 15   mob_diffcounty    B07001_049E      mob_diffcounty_pcp            mob_tot
# 16    mob_diffstate    B07001_065E       mob_diffstate_pcp            mob_tot
# 17    mob_diffcntry    B07001_081E       mob_diffcntry_pcp            mob_tot
# 18          pov_tot    B17002_001E      pov_tot_pcp_remove            pov_tot
# 19          pov_u50    B17002_002E             pov_u50_pcp            pov_tot
# 20        pov_50t74    B17002_003E           pov_50t74_pcp            pov_tot
# 21        pov_75t99    B17002_004E           pov_75t99_pcp            pov_tot
# 22      pov_100t124    B17002_005E         pov_100t124_pcp            pov_tot
# 23      pov_125t149    B17002_006E         pov_125t149_pcp            pov_tot
# 24      pov_150t174    B17002_007E         pov_150t174_pcp            pov_tot
# 25      pov_175t184    B17002_008E         pov_175t184_pcp            pov_tot
# 26      pov_185t199    B17002_009E         pov_185t199_pcp            pov_tot
# 27       me_medearn    B18140_001E          me_medearn_pcp                NaN
# 28         asst_tot    B22001_001E     asst_tot_pcp_remove           asst_tot
# 29        asst_rcvd    B22001_002E           asst_rcvd_pcp           asst_tot
# 30         empl_tot    B23025_001E     empl_tot_pcp_remove           empl_tot
# 31  empl_notinlabor    B23025_007E     empl_notinlabor_pcp           empl_tot
# 32         occu_tot    B25002_001E            occu_tot_pcp            pop_tot
# 33      occu_vacant    B25002_003E         occu_vacant_pcp            pop_tot
# 34       tenure_tot    B25003_001E          tenure_tot_pcp            pop_tot
# 35      tenure_rent    B25003_003E         tenure_rent_pcp            pop_tot
# 36        vcncy_tot    B25004_001E           vcncy_tot_pcp            pop_tot
# 37    vcncy_forrent    B25004_002E       vcncy_forrent_pcp            pop_tot
# 38    vcncy_forsale    B25004_004E       vcncy_forsale_pcp            pop_tot
# 39       hhsize_tot    B25010_001E          hhsize_tot_pcp                NaN
# 40       hhsize_own    B25010_002E          hhsize_own_pcp                NaN
# 41      hhsize_rent    B25010_003E         hhsize_rent_pcp                NaN
# 42       nbrrms_tot    B25021_001E          nbrrms_tot_pcp                NaN
# 43       nbrrms_own    B25021_002E          nbrrms_own_pcp                NaN
# 44      nbrrms_rent    B25021_003E         nbrrms_rent_pcp                NaN
# 45      rentpct_tot    B25070_001E  rentpct_tot_pcp_remove        rentpct_tot
# 46      rentpct_u10    B25070_002E         rentpct_u10_pcp        rentpct_tot
# 47    rentpct_10t14    B25070_003E       rentpct_10t14_pcp        rentpct_tot
# 48    rentpct_15t19    B25070_004E       rentpct_15t19_pcp        rentpct_tot
# 49    rentpct_20t24    B25070_005E       rentpct_20t24_pcp        rentpct_tot
# 50    rentpct_25t29    B25070_006E       rentpct_25t29_pcp        rentpct_tot
# 51    rentpct_30t34    B25070_007E       rentpct_30t34_pcp        rentpct_tot
# 52    rentpct_35t39    B25070_008E       rentpct_35t39_pcp        rentpct_tot
# 53    rentpct_40t49    B25070_009E       rentpct_40t49_pcp        rentpct_tot
# 54   rentpct_50plus    B25070_010E      rentpct_50plus_pcp        rentpct_tot
# 55   rentpct_median    B25071_001E      rentpct_median_pcp                NaN

# %%
# Save categories in a list to iterate through
categorylist = basedict['Category'].unique().tolist()
allfieldlist = basedict['ACS Field Name'].unique().tolist()
percaplist = basedict['Per Capita Value'].unique().tolist()
percaplist = [item for item in percaplist if "remove" not in item]

# Create tuples of category and field lists
catfields = []
for category in categorylist:
    fieldlist = basedict[basedict['Category']==category]['ACS Field Name'].tolist()
    fieldstr = ','.join(fieldlist)
    catfields.append((category,fieldstr))
    
# Create list of years for surveys to include
yearlist = [2011,2012,2013,2014,2015,2016,2017,2018,2019,2021]

# %%
# Iterate through the years of the survey
firstyear = True
for year in yearlist:
    print("Getting data for year", year)
    # Iterate through catfields and call ACS API
    firstcategory = True
    for item in catfields:
        # Construct the API call
        baseurl = "https://api.census.gov/data/" + str(year) + "/acs/acs1?get=NAME,"
        geostr = "&for=state:*"
        url = baseurl + item[1] + geostr

        payload = {}
        headers = {
            'Cookie': 'TS010383f0=01283c52a4bcbb7610e59eeaa15d8413e26e6fe3964ed3d6366923cf15872dc497c7b99977c06f32b40443b07f2820836b21943cf2'
        }
        
        # Call the API
        response = requests.request("GET", url, headers=headers, data=payload)

        # Save the response as json and create a pandas dataframe from it
        data = response.json()
        df = pd.DataFrame(data[1:], columns=data[0])
        
        if firstcategory:
            df.drop(['state'],axis=1,inplace=True)
            allcolsdf = df
            firstcategory = False
        else:
            df.drop(['NAME', 'state'],axis=1,inplace=True)
            allcolsdf = pd.concat([allcolsdf, df], axis=1)
            
    # Add year to dataframe and change NAME to state
    allcolsdf['year'] = year
    allcolsdf = allcolsdf.rename(columns={'NAME': 'state'})
    
    # Merge dataframe to prior years' dataframe
    if firstyear:
        allyearsdf = allcolsdf
        firstyear = False
    else:
        allyearsdf = pd.concat([allyearsdf, allcolsdf], axis=0)
# Out:
# Getting data for year 2011
# Getting data for year 2012
# Getting data for year 2013
# Getting data for year 2014
# Getting data for year 2015
# Getting data for year 2016
# Getting data for year 2017
# Getting data for year 2018
# Getting data for year 2019
# Getting data for year 2021

# %%
# Rename the columns from the ACS field name to the alias for the study
for acsname in allfieldlist:
    newname = basedict.loc[basedict['ACS Field Name'] == acsname, 'Alias'].values[0]
    allyearsdf.rename(columns={acsname : newname}, inplace=True)

# %%
# Convert data types in df from object to float
dontconvert = ['state', 'year']
convertlist = [item for item in allyearsdf.columns.tolist() if item not in dontconvert]

for item in convertlist:
    allyearsdf[item] = allyearsdf[item].astype(float)

# %%
# Generate the per capita features

# Setup a list to iterate through
calclist = []
for percapfield in percaplist:
    alias = basedict.loc[basedict['Per Capita Value'] == percapfield, 'Alias'].values[0]
    if basedict.loc[basedict['Per Capita Value'] == percapfield, 'Per Capita Divisor'].isnull().values[0]:
        divisor = 1
    else:
        divisor = basedict.loc[basedict['Per Capita Value'] == percapfield, 'Per Capita Divisor'].values[0]
    calclist.append((alias, percapfield, divisor)) 
    
# Create the calculated fields
for item in calclist:
    if item[2] == 1:
        allyearsdf[item[1]] = allyearsdf[item[0]]
    else:
        allyearsdf[item[1]] = allyearsdf[item[0]]/allyearsdf[item[2]]
# Out:
# /var/folders/sn/ltkf3r208xlffc006s6ld1_80000gn/T/ipykernel_15681/2105427430.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   allyearsdf[item[1]] = allyearsdf[item[0]]/allyearsdf[item[2]]
# /var/folders/sn/ltkf3r208xlffc006s6ld1_80000gn/T/ipykernel_15681/2105427430.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   allyearsdf[item[1]] = allyearsdf[item[0]]/allyearsdf[item[2]]
# /var/folders/sn/ltkf3r208xlffc006s6ld1_80000gn/T/ipykernel_15681/2105427430.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   allyearsdf[item[1]] = allyearsdf[item[0]]/allyearsdf[item[2]]
# /var/folders/sn/ltkf3r208xlffc006s6ld1_80000gn/T/ipykernel_15681/2105427430.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   allyearsdf[item[1]] = allyearsdf[item[0]]/allyearsdf[item[2]]
# /var/folders/sn/ltkf3r208xlffc006s6ld1_80000gn/T/ipykernel_15681/2105427430.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   allyearsdf[item[1]] = allyearsdf[item[0]]/allyearsdf[item[2]]
# /var/folders/sn/ltkf3r208xlffc006s6ld1_80000gn/T/ipykernel_15681/2105427430.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   allyearsdf[item[1]] = allyearsdf[item[0]]/allyearsdf[item[2]]
# /var/folders/sn/ltkf3r208xlffc006s6ld1_80000gn/T/ipykernel_15681/2105427430.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   allyearsdf[item[1]] = allyearsdf[item[0]]/allyearsdf[item[2]]
# /var/folders/sn/ltkf3r208xlffc006s6ld1_80000gn/T/ipykernel_15681/2105427430.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   allyearsdf[item[1]] = allyearsdf[item[0]]

# %%
# Defragment the dataframe
allyearsdf = allyearsdf.copy()

# Add in two character statecode
stateabbvdf = pd.read_csv('state_abbreviations.txt', sep='\t')
allyearsdf = pd.merge(allyearsdf, stateabbvdf, on='state')

# Save dataframe to a tab delimited file
allyearsdf.to_csv('acsdatafeatures.txt', sep='\t', index=False)
